# %%
import pandas as pd
import bs4
from urllib.request import urlopen
import urllib
import time
import tkinter as tk
from tkinter import messagebox
import datetime
import time
import re
import numpy as np
def kortime2engtime(time_string):
    today = datetime.datetime.today()
    number = int(re.findall('\d+', time_string)[0])
    kortime = ''.join(re.findall("[^0-9]",time_string))
    if kortime == '일' :
        before_date = datetime.timedelta(days=number)
    elif kortime == '분':
        before_date= datetime.timedelta(minutes=number)
    elif kortime == '시간' :
        before_date = datetime.timedelta(hours=number)
    elif kortime == '초' : 
        before_date = datetime.timedelta(seconds=number)
    else:
        return time_string
    save_date = (today-before_date).strftime('%Y.%m.%d')
    return save_date


def naver(search):
    searching = '''{}'''.format(search)
    searching = searching.strip()
    df_list = []
    start = 1
    start_date = '2021.01.01'
    end_date = '2021.10.31'
    keyword = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', ' ', searching).split()
    op = re.findall('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', searching)

    plus = [keyword[0]]

    for index, value in enumerate(op):
        if value == '+':
            plus.extend([keyword[index+1]])

    new = keyword[0]
    for k,o in zip(keyword[1:],op):
        if len(keyword) ==1:
            break
        else:
            new += ' '+o+k
    word_encode = urllib.parse.quote(new)
    
    while True:
        url='''https://search.naver.com/search.naver?where=news&query={}&sm=tab_opt&sort=0&photo=0&field=0&pd=3&ds={}&de={}&start={}'''.format(word_encode,start_date,end_date,start)
        source = urlopen(url).read()
        source = urlopen(url).read()
        source = bs4.BeautifulSoup(source, 'html.parser')
        title_path = source.find_all('a', {'class': 'news_tit'})
        abstract_path = source.find_all('a', {'class': 'api_txt_lines dsc_txt_wrap'})
        date_path = source.find_all('span', {'class': 'info'})
        for idx,v in enumerate(date_path):
            if v.find('i'):
                date_path.pop(idx)

        if len(title_path) == 0:
            root = tk.Tk()
            msg = messagebox.showerror(title="Naver No news", message='please search other keyword')
            if msg == 'ok':
                root.destroy()
                break

        for i in range(len(title_path)):
            title = title_path[i].get('title')

            if all(key in title for key in plus):
                abstract = abstract_path[i].text
                link = title_path[i].get('href')
                date_txt = date_path[i].text
                try:
                    date = kortime2engtime(date_txt.split()[0])
                except:
                    date = date_txt
                    print(date)
                    pass
                df = pd.DataFrame(
                    {'title': [title], 'abstract': [abstract], 'url': [link], 'date': [date],
                        'engine': ['naver']})
                df_list.append(df)


        current_page = source.find_all('a', {'aria-pressed': 'true'})[0].text
        last_page = source.find_all('a', {'aria-pressed': 'false'})[-1].text
        if last_page == '문서 저장하기':
            break

        if int(current_page) >= int(last_page):
            break
        else:
            start += 10
        time.sleep(0.5)

        print('crawling...')


    if df_list:
            naver_df = pd.concat(df_list)
            new = new.replace('|',' ')
            naver_df.to_excel('''naver_{}_result.xlsx'''.format(new),index=False)

            root2 = tk.Tk()
            msg = messagebox.showinfo(title='Save msg',message='Naver Save!')
            if msg == 'ok':
                root2.destroy()
            return naver_df
    else:
        root3 = tk.Tk()
        msg = messagebox.showerror(title = "Naver No news",message = 'please search other keyword')
        if msg == 'ok':
            root3.destroy()

# %%
naver('삼성전자')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# CHIEF EXECUTIVE
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
#                                            title  \
# 0                    네이버의 '키워드 리뷰' 새 가게평가 문화로 호평
# 0                    네이버-이마트-쿠팡, 빅커머스 1위 쟁탈전 본격화
# 0   “네이버 검색량 보니···” 尹 ‘398’ 리스크 재확인[데이터로 본 정치민심]
# 0            [IT돋보기] 네이버 검색, AI 재탄생…"정답에 취향 더한다"
# 0           네이버 '키워드 리뷰' 개시…기존 '별점 리뷰' 내년 1분기 중단
# ..                                           ...
# 0             [더벨]금융사업 구조조정…'급한' 카카오 vs '여유' 네이버
# 0               '테크래시' 직격탄 맞은 빅테크…네이버는 규제 청정 구역?
# 0                  플랫폼 논란 예견했나...네이버가 5년전 심은 '꽃'
# 0   [단독] 네이버 해피빈 ‘직장갑질’ 폭로 뒤 “가해자 구명 탄원서 써달라” 요구
# 0              네이버에 종속된 저축은행…'광고비 부담' 결국 고객에게 간다
#
#                                              abstract  \
# 0   네이버가 최근 도입한 '키워드 리뷰'가 새로운 가게 평가 문화로 각광받고 있다. 키...
# 0   규제 당국의 신세계 그룹 이마트-이베이코리아 기업결합 승인으로, 국내 이커머스 시장...
# 0   국민의힘 대선 경선 투표 시작을 하루 앞둔 31일, 유력 주자인 윤 후보가 풀어야 ...
# 0   #네이버에 캠핑을 검색하자, ▲캠핑 준비물 리스트 ▲초보캠핑 ▲캠핑장비 ▲감성캠핑 ...
# 0   네이버는 오프라인 중소상공인(SME) 대상 새 리뷰 시스템 '키워드 리뷰'를 26일...
# ..                                                ...
# 0   금융소비자보호법이 조만간 실시되면 네이버와 카카오의 금융사업은 좀 더 타이트한 규제...
# 0   미국 유럽 등의 빅테크 규제가 국내에서도 확산될 우려가 커지면서 국내 증시에서도 네...
# 0   " 2016년 당시 한성숙 네이버 서비스총괄부사장(현 대표)은 '프로젝트 꽃'을 발...
# 0   최근 직장 내 괴롭힘 피해 폭로가 나온 네이버 해피빈 재단 관계자들이 가해자로 지목...
# 0   네이버 등 빅테크 플랫폼의 영향력이 커지면서 저축은행들의 광고비 규모도 덩달아 커진...
#
#                                                   url         date engine
# 0       http://www.fnnews.com/news/202110311507252414  2021.10.31.  naver
# 0         https://zdnet.co.kr/view/?no=20211029184850  2021.10.29.  naver
# 0         https://www.sedaily.com/NewsView/22SYCNEBGU  2021.10.31.  naver
# 0                 http://www.inews24.com/view/1416237  2021.10.28.  naver
# 0        http://yna.kr/AKR20211027080500017?did=1195m  2021.10.27.  naver
# ..                                                ...          ...    ...
# 0   http://www.thebell.co.kr/front/free/contents/n...  2021.09.14.  naver
# 0   http://www.newstomato.com/ReadNews.aspx?no=107...  2021.09.14.  naver
# 0   http://news.mt.co.kr/mtview.php?no=20210913160...  2021.09.14.  naver
# 0   https://www.hani.co.kr/arti/society/society_ge...  2021.09.14.  naver
# 0   http://news.mt.co.kr/mtview.php?no=20210913152...  2021.09.14.  naver
#
# [3939 rows x 5 columns]

# %%
naver('기업은행')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1fe6ae35e47e> in <module>
# ----> 1 naver('기업은행')
#
# <ipython-input-4-d97688dec4ba> in naver(search)
#      99         else:
#     100             start += 10
# --> 101         time.sleep(0.5)
#     102
#     103         print('crawling...')
#
# KeyboardInterrupt:

# %%
import pandas as pd
import bs4
from urllib.request import urlopen
import urllib
import tkinter as tk
from tkinter import messagebox
import datetime
import time
import re


def kortime2engtime(time_string):
    today = datetime.datetime.today()
    number = int(re.findall('\d+', time_string)[0])
    kortime = ''.join(re.findall("[^0-9]",time_string))
    if kortime == '일' :
        before_date = datetime.timedelta(days=number)
    elif kortime == '분':
        before_date= datetime.timedelta(minutes=number)
    elif kortime == '시간' :
        before_date = datetime.timedelta(hours=number)
    elif kortime == '초' :
        before_date = datetime.timedelta(seconds=number)
    else:
        return time_string
    save_date = (today-before_date).strftime('%Y.%m.%d')
    return save_date


def naver(search,start_date,end_date):
    searching = '''{}'''.format(search)
    searching = searching.strip()
    df_list = []
    start = 1
    keyword = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', ' ', searching).split()
    op = re.findall('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', searching)

    plus = [keyword[0]]

    for index, value in enumerate(op):
        if value == '+':
            plus.extend([keyword[index+1]])

    new = keyword[0]
    for k,o in zip(keyword[1:],op):
        if len(keyword) ==1:
            stop = True
            break

        else:
            new += ' '+o+k
    word_encode = urllib.parse.quote(new)

    while True:
        url='''https://search.naver.com/search.naver?where=news&query={}&sm=tab_opt&sort=0&photo=4&field=0&pd=3&ds={}&de={}&start={}'''.format(word_encode,start_date,end_date,start)
        source = urlopen(url).read()
        source = bs4.BeautifulSoup(source, 'html.parser')
        title_path = source.find_all('a', {'class': 'news_tit'})
        abstract_path = source.find_all('a', {'class': 'api_txt_lines dsc_txt_wrap'})
        date_path = source.find_all('span', {'class': 'info'})

        if len(title_path) == 0:
            root = tk.Tk()
            msg = messagebox.showerror(title="Naver No news", message='please search other keyword')
            if msg == 'ok':
                root.destroy()
                break

        for i in range(len(title_path)):
            title = title_path[i].get('title')

            if all(key in title for key in plus):
                abstract = abstract_path[i].text
                link = title_path[i].get('href')
                date_txt = date_path[i].text
                date = kortime2engtime(date_txt.split()[0])
                df = pd.DataFrame(
                    {'title': [title], 'abstract': [abstract], 'url': [link], 'date': [date],
                        'engine': ['naver']})
                df_list.append(df)
             

        current_page = source.find_all('a', {'aria-pressed': 'true'})[0].text
        last_page = source.find_all('a', {'aria-pressed': 'false'})[-1].text
        if last_page == '문서 저장하기':
            break

        if int(current_page) >= int(last_page):
            break
        else:
            start += 10
        time.sleep(0.5)
        
        print('crawling...')

    if df_list:
            naver_df = pd.concat(df_list)
            st = ''.join(start_date.split('.')[1:])
            et = ''.join(end_date.split('.')[1:])
            naver_df.to_excel('''naver_{}_result_{}_{}.xlsx'''.format(searching,st,et),index=False)
            
            root2 = tk.Tk()
            msg = messagebox.showinfo(title='Save msg',message='Naver Save!')
            if msg == 'ok':
                root2.destroy()
            return naver_df
    else:
        root3 = tk.Tk()
        msg = messagebox.showerror(title = "Naver No news",message = 'please search other keyword')
        if msg == 'ok':
            root3.destroy()

#     df = pd.concat(df_list)
#     new = new.replace('|',' ')
#     st = ''.join(start_date.split('.')[1:])
#     et = ''.join(end_date.split('.')[1:])
#     df.to_excel('''naver_{}_result_{}_{}.xlsx'''.format(new,st,et), index=False)

# %%
naver('삼성전자','2021.11.01','2021.11.15')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
#                                           title  \
# 0                     삼성전자, ‘2022 상하이 기능올림픽’ 후원
# 0                     삼성전자, 외부 급식업체 경쟁 입찰 결과 발표
# 0                   삼성전자, ‘CES 2022 혁신상’ 43개 수상
# 0                삼성전자 한종희 사장, CES 2022 기조연설 나선다
# 0       삼성전자, 고성능 반도체용 2.5D 패키징 솔루션 'H-Cube' 개발
# 0             삼성전자, 차세대 2.5D 패키지 기술 'H-Cube' 개발
# 0            삼성전자, 차세대 2.5D 패키징 솔루션 ‘H-Cube’ 개발
# 0         삼성전자, 업계 최초 LPDDR5X D램 개발…5G 서비스에 최적화
# 0                      에너자이, 삼성전자 ‘C랩 아웃사이드’ 선정
# 0            삼성전자, ‘2021 삼성 주니어 SW 창작대회’ 시상식 개최
# 0            소재 부품 장비 산업 돋보였다…삼성전자 부사장 등 18인 수상
# 0  삼성전자, 스타트업 투자 유치와 사업 협력 위한 ‘C랩 스타트업 데모데이’ 개최
# 0                  삼성전자, CJ와 ‘HDR10+’ 적용 콘텐츠 확대
# 0                 삼성전자, ‘갤럭시 워치4 PXG 골프 에디션’ 출시
# 0           [삼성전자] 겉만 번지르르 아니에요…갤럭시 플립 알짜기능 수두룩
# 0       G마켓·옥션, 빅스마일데이 삼성전자·타미힐피거·LG생활건강 등 흥행몰이
# 0        삼성전자, CJ와 HDR10+ 적용 콘텐츠 확대...전환 솔루션 검증
# 0                       삼성전자, 제5회 ‘삼성 AI 포럼’ 개최
# 0                          삼성전자, 제52주년 창립기념식 개최
# 0              삼성전자, ‘사람의 삶을 향상시키는 AI’ 연구 성과 논의
# 0                   삼성전자, ‘비스포크 큐커’ 전용 메뉴 대폭 확대
# 0          삼성전자 DS부문, 용인시 사회복지시설 및 단체에 차량 8대 전달
# 0           삼성전자, 창립 52주년 기념식…"초일류 100년 기업 만들자"
#
#                                             abstract  \
# 0  삼성전자는 국제기능올림픽위원회와 ‘2022 상하이 국제기능올림픽’ 후원 계약을 체결...
# 0  삼성전자가 11일 사내식당 6곳에 대해 실시한 외부 급식업체 경쟁 입찰 결과를 발표...
# 0  서울--(뉴스와이어) 삼성전자가 내년 1월 미국 라스베이거스에서 열리는 세계 최대 ...
