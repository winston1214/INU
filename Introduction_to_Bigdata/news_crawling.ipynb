# %%
import pandas as pd
import bs4
from urllib.request import urlopen
import urllib
import time
import tkinter as tk
from tkinter import messagebox
import datetime
import time
import re
def kortime2engtime(time_string):
    today = datetime.datetime.today()
    number = int(re.findall('\d+', time_string)[0])
    kortime = ''.join(re.findall("[^0-9]",time_string))
    if kortime == '일' :
        before_date = datetime.timedelta(days=number)
    elif kortime == '분':
        before_date= datetime.timedelta(minutes=number)
    elif kortime == '시간' :
        before_date = datetime.timedelta(hours=number)
    elif kortime == '초' : 
        before_date = datetime.timedelta(seconds=number)
    else:
        return time_string
    save_date = (today-before_date).strftime('%Y.%m.%d')
    return save_date


def naver(search):
    searching = '''{}'''.format(search)
    searching = searching.strip()
    df_list = []
    start = 1
    start_date = '2021.01.02'
    end_date = '2021.10.16'
    keyword = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', ' ', searching).split()
    op = re.findall('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', searching)

    plus = [keyword[0]]

    for index, value in enumerate(op):
        if value == '+':
            plus.extend([keyword[index+1]])

    new = keyword[0]
    for k,o in zip(keyword[1:],op):
        if len(keyword) ==1:
            break
        else:
            new += ' '+o+k
    word_encode = urllib.parse.quote(new)

    while True:
        url='''https://search.naver.com/search.naver?where=news&query={}&sm=tab_opt&sort=0&photo=0&field=0&pd=3&ds={}&de={}&start={}'''.format(word_encode,start_date,end_date,start)
        source = urlopen(url).read()
        source = urlopen(url).read()
        source = bs4.BeautifulSoup(source, 'html.parser')
        title_path = source.find_all('a', {'class': 'news_tit'})
        abstract_path = source.find_all('a', {'class': 'api_txt_lines dsc_txt_wrap'})
        date_path = source.find_all('span', {'class': 'info'})
        for idx,v in enumerate(date_path):
            if v.find('i'):
                date_path.pop(idx)
        
        if len(title_path) == 0:
            root = tk.Tk()
            msg = messagebox.showerror(title="Naver No news", message='please search other keyword')
            if msg == 'ok':
                root.destroy()
                break

        for i in range(len(title_path)):
            title = title_path[i].get('title')

            if all(key in title for key in plus):
                abstract = abstract_path[i].text
                link = title_path[i].get('href')
                date_txt = date_path[i].text
                
                date = kortime2engtime(date_txt.split()[0])
                df = pd.DataFrame(
                    {'title': [title], 'abstract': [abstract], 'url': [link], 'date': [date],
                        'engine': ['naver']})
                df_list.append(df)
             

        current_page = source.find_all('a', {'aria-pressed': 'true'})[0].text
        last_page = source.find_all('a', {'aria-pressed': 'false'})[-1].text
        if last_page == '문서 저장하기':
            break

        if int(current_page) >= int(last_page):
            break
        else:
            start += 10
        time.sleep(0.5)
        
        print('crawling...')

    if df_list:
            naver_df = pd.concat(df_list)
            new = new.replace('|',' ')
            naver_df.to_excel('''naver_{}_result.xlsx'''.format(new),index=False)

            root2 = tk.Tk()
            msg = messagebox.showinfo(title='Save msg',message='Naver Save!')
            if msg == 'ok':
                root2.destroy()
            return naver_df
    else:
        root3 = tk.Tk()
        msg = messagebox.showerror(title = "Naver No news",message = 'please search other keyword')
        if msg == 'ok':
            root3.destroy()

# %%
naver('삼성전자')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
#                                  title  \
# 0             "20일 삼성전자 언팩, '이것' 공개된다"
# 0    "삼성전자 지금 사야 돈 번다"…개미들 2조 '줍줍'한 이유
# 0      떨어지는 삼성전자 잡는 개미들…열흘간 3조원 넘게 순매수
# 0        삼성전자가 미국기업도 아닌데…또 호출한 바이든, 왜?
# 0          삼성전자, 5G 업로드 세계 신기록 달성…비결은?
# ..                                 ...
# 0    삼성전자 3Q 반도체 매출, 파운드리 빼고도 세계 1위할 듯
# 0          [특징주] 삼성전자, 5일 7만2000원도 깨졌다
# 0     삼성전자 노사 오늘 첫 임금교섭…급여 50% 인상 성사되나
# 0                 삼성전자 온실가스 저감율 업체 최하위
# 0   파운드리시장 점유율 높인 TSMC, 삼성전자와 격차 더 벌렸다
#
#                                              abstract  \
# 0   삼성전자의 갤럭시S21 FE(팬에디션)가 이번 달 출시될 것이라는 전망이 나왔다. ...
# 0   개미(개인투자자)들의 삼성전자 사랑이 여전하다. 삼성전자가 3거래일 만에 '7만전자...
# 0   주가, 연고점 대비 29% 하락…10개월 만에 '6만전자' 증권가, 반도체 업황 우...
# 0   조 바이든 미국 대통령이 미국 내 물류대란을 해결하기 위해 민간기업의 협조를 요청하...
# 0   삼성전자는 5G 이동통신 업로드 속도에서 세계 최고 기록을 달성했다고 15일 밝혔다...
# ..                                                ...
# 0   삼성전자가 올해 3분기 파운드리(반도체 위탁생산) 매출을 제외하고도 글로벌 반도체 ...
# 0   삼성전자가 5일 7만1000원대까지 떨어지는 등 연중 최저가를 기록했다. 삼성전자는...
# 0   삼성전자 노사가 5일 창사 이래 첫 임금교섭에 돌입한다. 이번 교섭은 지난해 5월 ...
# 0   우리나라 반도체, 디스플레이, 전자산업 5대 기업의 불소가스(F-gas) 사용업체별...
# 0   반도체 위탁생산(파운드리) 시장에서 세계 1위 TSMC와 2위 삼성전자의 격차가 더...
#
#                                                   url         date engine
# 0   http://moneys.mt.co.kr/news/mwView.php?no=2021...   2021.10.15  naver
# 0   https://www.hankyung.com/finance/article/20211...   2021.10.16  naver
# 0        http://yna.kr/AKR20211013173100002?did=1195m   2021.10.14  naver
# 0   http://news.mt.co.kr/mtview.php?no=20211015154...   2021.10.16  naver
# 0   http://www.sisaon.co.kr/news/articleView.html?...   2021.10.15  naver
# ..                                                ...          ...    ...
# 0   https://view.asiae.co.kr/article/2021092010181...  2021.09.20.  naver
# 0   http://news.heraldcorp.com/view.php?ud=2021100...  2021.10.05.  naver
# 0   https://www.asiatoday.co.kr/view.php?key=20211...  2021.10.05.  naver
# 0   http://www.kmaeil.com/news/articleView.html?id...  2021.10.06.  naver
# 0                 http://www.inews24.com/view/1408580  2021.10.01.  naver
#
# [2747 rows x 5 columns]

# %%
naver('네이버')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-8570c255c72f> in <module>
# ----> 1 naver('네이버')
#
# <ipython-input-8-656622ac22a6> in naver(search)
#      78                 date_txt = date_path[i].text
#      79
# ---> 80                 date = kortime2engtime(date_txt.split()[0])
#      81                 df = pd.DataFrame(
#      82                     {'title': [title], 'abstract': [abstract], 'url': [link], 'date': [date],
#
# <ipython-input-8-656622ac22a6> in kortime2engtime(time_string)
#      11 def kortime2engtime(time_string):
#      12     today = datetime.datetime.today()
# ---> 13     number = int(re.findall('\d+', time_string)[0])
#      14     kortime = ''.join(re.findall("[^0-9]",time_string))
#      15     if kortime == '일' :
#
# IndexError: list index out of range

# %%
naver('기업은행')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
#                                            title  \
# 0         민형배 “기업은행, 중기대출 30%는 꺾기 의심…근절 대책 내놓아야”
# 0           [2021 국감] 기업은행 "성남의뜰에서 수수료 63억원 받았다"
# 0            기업은행장 “중도상환수수료 일시 면제 검토… 대출 여력은 충분”
# 0                     IBK기업은행·삼성SDS, 수출기업 응원 이벤트
# 0     여자배구 IBK기업은행 내일 시즌 첫 경기…굿즈 '품절 대란' 인기 이어가나
# ..                                           ...
# 0   [A 금융가 소식] IBK기업은행, '2021 중견기업 일자리 박람회' 개최 外
# 0          농협銀에 이어 기업은행마저… 무더기 제재에 내부통제 부실 지적 나와
# 0                기업은행, 中企 일자리 비대면 간담회 26일 유튜브 중계
# 0               IBK기업은행, 임대료 최대 50% 인하…中企 부담 덜었다
# 0   기업은행, '2021 중견기업 일자리 박람회' 개최...'기업 70여 곳 참여'
#
#                                              abstract  \
# 0   최근 3년간 기업은행 중소기업 대출 3건 중 1건은 꺾기가 의심되는 거래였으며 건수...
# 0   IBK기업은행이 경기 성남기 대장동 개발사업의 시행사인 '성남의뜰'로부터 수수료 약...
# 0   윤종원 IBK기업은행장은 15일 열린 정무위원회 국정감사에서 중도상환수수료를 인하하...
# 0   IBK기업은행은 글로벌 물류서비스를 제공하는 삼성SDS와 함께 물류비 상승으로 어려...
# 0   도쿄올림픽 이후 한국 여자배구 대표팀을 향한 응원과 관심이 치솟고 있는 가운데 김희...
# ..                                                ...
# 0   ◇IBK기업은행, '2021 중견기업 일자리 박람회' 개최 IBK기업은행은 6월 4...
# 0   위법 행위 수준 밝히지 않아 징계에도 불구, 투명성 논란 최근 농협은행 직원들의 잇...
# 0   IBK기업은행은 오는 26일 코로나 시대 중소기업 채용 동향과 현장 의견을 듣기 위...
# 0   기업은행은 중소기업 근로자와 근로자 가족을 위한 사회공헌활동에 앞장서고 있다. 코로...
# 0   IBK기업은행 '2021 중견기업 일자리 박람회'개최 (사진, IBK기업은행) IB...
#
#                                                   url         date engine
# 0   http://www.joseilbo.com/news/news_read.php?uid...   2021.10.15  naver
# 0                 http://www.inews24.com/view/1412384   2021.10.15  naver
# 0   https://biz.chosun.com/stock/finance/2021/10/1...   2021.10.15  naver
# 0   http://www.edaily.co.kr/news/newspath.asp?news...   2021.10.15  naver
# 0   http://mbn.mk.co.kr/pages/news/newsView.php?ca...   2021.10.16  naver
# ..                                                ...          ...    ...
# 0   http://www.asiaa.co.kr/news/articleView.html?i...  2021.05.24.  naver
# 0   http://www.newscj.com/news/articleView.html?id...  2021.05.24.  naver
# 0   http://www.kbiznews.co.kr/news/articleView.htm...  2021.05.24.  naver
# 0   https://www.hankyung.com/society/article/20210...  2021.05.24.  naver
# 0   http://www.idsn.co.kr/news/articleView.html?id...  2021.05.24.  naver
#
# [3043 rows x 5 columns]

# %%
import pandas as pd
import bs4
from urllib.request import urlopen
import urllib
import tkinter as tk
from tkinter import messagebox
import datetime
import time
import re


def kortime2engtime(time_string):
    today = datetime.datetime.today()
    number = int(re.findall('\d+', time_string)[0])
    kortime = ''.join(re.findall("[^0-9]",time_string))
    if kortime == '일' :
        before_date = datetime.timedelta(days=number)
    elif kortime == '분':
        before_date= datetime.timedelta(minutes=number)
    elif kortime == '시간' :
        before_date = datetime.timedelta(hours=number)
    elif kortime == '초' :
        before_date = datetime.timedelta(seconds=number)
    else:
        return time_string
    save_date = (today-before_date).strftime('%Y.%m.%d')
    return save_date


def naver(search):
    searching = '''{}'''.format(search)
    searching = searching.strip()
    df_list = []
    start = 1
    keyword = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', ' ', searching).split()
    op = re.findall('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', searching)

    plus = [keyword[0]]

    for index, value in enumerate(op):
        if value == '+':
            plus.extend([keyword[index+1]])

    new = keyword[0]
    for k,o in zip(keyword[1:],op):
        if len(keyword) ==1:
            stop = True
            break

        else:
            new += ' '+o+k
    word_encode = urllib.parse.quote(new)

    while True:
        url = 'https://search.naver.com/search.naver?where=news&sm=tab_jum&query={}&pd=1&start={}'.format(word_encode,
                                                                                                          start)
        source = urlopen(url).read()
        source = bs4.BeautifulSoup(source, 'html.parser')
        title_path = source.find_all('a', {'class': 'news_tit'})
        abstract_path = source.find_all('a', {'class': 'api_txt_lines dsc_txt_wrap'})
        date_path = source.find_all('span', {'class': 'info'})

        if len(title_path) == 0:
            root = tk.Tk()
            msg = messagebox.showerror(title="Naver No news", message='please search other keyword')
            if msg == 'ok':
                root.destroy()
                break

        for i in range(len(title_path)):
            title = title_path[i].get('title')

            if all(key in title for key in plus):
                abstract = abstract_path[i].text
                link = title_path[i].get('href')
                date_txt = date_path[i].text
                date = kortime2engtime(date_txt.split()[0])
                df = pd.DataFrame(
                    {'title': [title], 'abstract': [abstract], 'url': [link], 'date': [date],
                        'engine': ['naver']})
                df_list.append(df)
             

        current_page = source.find_all('a', {'aria-pressed': 'true'})[0].text
        last_page = source.find_all('a', {'aria-pressed': 'false'})[-1].text
        if last_page == '문서 저장하기':
            break

        if int(current_page) >= int(last_page):
            break
        else:
            start += 10
        time.sleep(0.5)
        
        print('crawling...')

    if df_list:
            naver_df = pd.concat(df_list)
            naver_df.to_excel('''naver_{}_result.xlsx'''.format(searching),index=False)

            root2 = tk.Tk()
            msg = messagebox.showinfo(title='Save msg',message='Naver Save!')
            if msg == 'ok':
                root2.destroy()
            return naver_df
    else:
        root3 = tk.Tk()
        msg = messagebox.showerror(title = "Naver No news",message = 'please search other keyword')
        if msg == 'ok':
            root3.destroy()

    df = pd.concat(df_list)
    new = new.replace('|',' ')
    df.to_excel('''naver_{}_result.xlsx'''.format(new), index=False)

# %%
naver('네이버')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
#                                             title  \
# 0                     결국 국감 소환된 네이버 이해진…과방위 증인 채택
# 0                      네이버클라우드, 강원도 기업 디지털 전환 돕는다
# 0                 네이버와 한 몸된 '검색 핵심' 서치솔루션은 어떤 기업?
# 0                      네이버 카카오 콘텐츠 제휴 합격사 하나도 없었다
# 0                               네이버 장보기에 '쓱' 들어갔네
# ..                                            ...
# 0         10월 12일 합창 서사시 '훈민정음' 초연 네이버 tv 실황 중계
# 0   [소비이슈] 엔유씨전자, 저당식밥솥 네이버 쇼핑라이브 진행... 최대 39% 할인
# 0             '다윈 영의 악의 기원' 윤형렬X김용한, 네이버 '커튼콜' 출연
# 0                      깨끗한나라, 네이버서 아동학대 예방 캠페인 진행
# 0                            네이버·카카오 웹소설 저작권침해 논란
#
#                                              abstract  \
# 0   ‘플랫폼 국감’에도 나홀로 빠졌던 네이버 창업자 건강·해외출장 등 사유로 불출석 가...
# 0   기사내용 요약GTI EXPO 2021서 4개국어 동시통번역 솔루션 '파파고 미트' ...
# 0   이달 초 네이버와 한 몸이 된 서치솔루션은 네이버 검색의 핵심 역할을 담당하고 있다...
# 0   네이버 뉴스스탠드에는 뉴스포스트, AI타임스가 신규 입점했다. 검색제휴 언론사의 경...
# 0   네이버 장보기에 SSG닷컴이 입점하면서 네이버와 신세계그룹의 동맹이 가시화되고 있다...
# ..                                                ...
# 0   탁계석 비평가회장 네이버 TV로 콘서트 실황 중계 '탁계석 대본 칸타타' 의... ...
# 0   건강가전 브랜드 엔유씨전자가 12일 오전 11시 '저당식밥솥' 런칭 1주년을 기념하...
# 0   배우 윤형렬과 김용한이 네이버 NOW. '커튼콜'에 게스트로 출연한다. 사진=네이버...
# 0   깨끗한나라가 아동학대 예방을 위해 네이버 해피빈에서 '깨끗한 마음 칠하기' 캠페인을...
# 0   지난 9월 대한출판문화협회가 카카오와 네이버의 출판 생태계 파괴행위 시정을 촉구한다...
#
#                                                   url        date engine
# 0   https://biz.chosun.com/it-science/ict/2021/10/...  2021.10.15  naver
# 0   http://www.newsis.com/view/?id=NISX20211015_00...  2021.10.15  naver
# 0      http://www.bloter.net/newsView/blt202110150084  2021.10.16  naver
# 0   http://www.mediatoday.co.kr/news/articleView.h...  2021.10.15  naver
# 0         https://www.sedaily.com/NewsView/22SQKXQM0D         16면  naver
# ..                                                ...         ...    ...
# 0   http://www.nbnnews.co.kr/news/articleView.html...  2021.10.10  naver
# 0   http://www.sisunnews.co.kr/news/articleView.ht...  2021.10.12  naver
# 0   http://www.slist.kr/news/articleView.html?idxn...  2021.10.12  naver
# 0   http://www.enewstoday.co.kr/news/articleView.h...  2021.10.15  naver
# 0                      http://munhaknews.com/?p=54737  2021.10.12  naver
#
# [739 rows x 5 columns]
