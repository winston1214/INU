# %%
import pandas as pd
import bs4
from urllib.request import urlopen
import urllib
import time
import tkinter as tk
from tkinter import messagebox
import datetime
import time
import re
import numpy as np
def kortime2engtime(time_string):
    today = datetime.datetime.today()
    number = int(re.findall('\d+', time_string)[0])
    kortime = ''.join(re.findall("[^0-9]",time_string))
    if kortime == '일' :
        before_date = datetime.timedelta(days=number)
    elif kortime == '분':
        before_date= datetime.timedelta(minutes=number)
    elif kortime == '시간' :
        before_date = datetime.timedelta(hours=number)
    elif kortime == '초' : 
        before_date = datetime.timedelta(seconds=number)
    else:
        return time_string
    save_date = (today-before_date).strftime('%Y.%m.%d')
    return save_date


def naver(search):
    searching = '''{}'''.format(search)
    searching = searching.strip()
    df_list = []
    start = 1
    start_date = '2021.01.01'
    end_date = '2021.10.31'
    keyword = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', ' ', searching).split()
    op = re.findall('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', searching)

    plus = [keyword[0]]

    for index, value in enumerate(op):
        if value == '+':
            plus.extend([keyword[index+1]])

    new = keyword[0]
    for k,o in zip(keyword[1:],op):
        if len(keyword) ==1:
            break
        else:
            new += ' '+o+k
    word_encode = urllib.parse.quote(new)
    
    while True:
        url='''https://search.naver.com/search.naver?where=news&query={}&sm=tab_opt&sort=0&photo=0&field=0&pd=3&ds={}&de={}&start={}'''.format(word_encode,start_date,end_date,start)
        source = urlopen(url).read()
        source = urlopen(url).read()
        source = bs4.BeautifulSoup(source, 'html.parser')
        title_path = source.find_all('a', {'class': 'news_tit'})
        abstract_path = source.find_all('a', {'class': 'api_txt_lines dsc_txt_wrap'})
        date_path = source.find_all('span', {'class': 'info'})
        for idx,v in enumerate(date_path):
            if v.find('i'):
                date_path.pop(idx)

        if len(title_path) == 0:
            root = tk.Tk()
            msg = messagebox.showerror(title="Naver No news", message='please search other keyword')
            if msg == 'ok':
                root.destroy()
                break

        for i in range(len(title_path)):
            title = title_path[i].get('title')

            if all(key in title for key in plus):
                abstract = abstract_path[i].text
                link = title_path[i].get('href')
                date_txt = date_path[i].text
                try:
                    date = kortime2engtime(date_txt.split()[0])
                except:
                    date = date_txt
                    print(date)
                    pass
                df = pd.DataFrame(
                    {'title': [title], 'abstract': [abstract], 'url': [link], 'date': [date],
                        'engine': ['naver']})
                df_list.append(df)


        current_page = source.find_all('a', {'aria-pressed': 'true'})[0].text
        last_page = source.find_all('a', {'aria-pressed': 'false'})[-1].text
        if last_page == '문서 저장하기':
            break

        if int(current_page) >= int(last_page):
            break
        else:
            start += 10
        time.sleep(0.5)

        print('crawling...')


    if df_list:
            naver_df = pd.concat(df_list)
            new = new.replace('|',' ')
            naver_df.to_excel('''naver_{}_result.xlsx'''.format(new),index=False)

            root2 = tk.Tk()
            msg = messagebox.showinfo(title='Save msg',message='Naver Save!')
            if msg == 'ok':
                root2.destroy()
            return naver_df
    else:
        root3 = tk.Tk()
        msg = messagebox.showerror(title = "Naver No news",message = 'please search other keyword')
        if msg == 'ok':
            root3.destroy()

# %%
naver('삼성전자')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
#                                          title  \
# 0          삼성전자 52주년 창립기념식…이재용 불참 속 사장단만 참석 전망
# 0          北 매체, 삼성전자에 이어 '오징어게임'으로 '한미불공평' 부각
# 0             삼성전자, 창립기념일 맞아 '삼성위크' 가전 프로모션 기획
# 0               여전한 개미의 삼성전자 사랑…外人 물량 2.5조 받아내
# 0            실탄 120兆 든 삼성전자…美 반도체 공장·대형M&A 초읽기
# ..                                         ...
# 0   ‘실적왕’ 삼성전자, D램 값에 내년 실적 어둡다는데…비메모리 전망 ‘맑음’
# 0             삼성전자 '6만전자'로 추락...33조 투자한 개미 어쩌나
# 0               [특징주] 삼성전자, 다시 7만원 하회…0.8%대 약세
# 0            [개장시황] 삼성전자 2% 넘게 하락하며 장중 7만전자 깨져
# 0         상속세 납부 위해 법원에 공탁한 삼성家 삼성전자 주식 5조원 규모
#
#                                              abstract  \
# 0   11월1일인 삼성전자 창립기념식에는 이재용 부회장이 불참할 것으로 예상됩니다. 오늘...
# 0   핵심요약넷플릭스 계약 "南 제작비의 10%만 받아 美 기업 배만 불려" "南 영화제...
# 0   삼성전자가 창립 52주년을 맞아 글로벌 시장에서 주요 제품을 할인해 판매하는 '삼성...
# 0   삼성전자(005930)가 다시 6만전자로 내려가자 개인투자자들의 주워담기 강도도 거...
# 0   삼성전자가 1일 창립 52주년을 맞는 가운데 120조원에 달하는 현금 실탄을 어디에...
# ..                                                ...
# 0   삼성전자가 반도체 호황에 힘입어 분기 매출 70조원 시대를 열었다. 하지만 디(D)...
# 0   삼성전자 주가가 7만원 밑으로 추락하면서 실적 호재를 믿고 투자한 개인 투자자들이 ...
# 0   삼성전자가 다시 7만원대 아래로 떨어졌다. 18일 오전 9시 16분 현재 삼성전자는...
# 0   시가총액 상위 주요 종목 가운데 삼성전자는 전 거래일 7만1500원보다 2.24% ...
# 0   이부진, 지난달 1조원 규모 삼성전자 주식 법원 공탁 이재용 삼성전자 부회장 등 삼...
#
#                                                   url         date engine
# 0   https://biz.sbs.co.kr/article_hub/20000036495?...  2021.10.31.  naver
# 0            https://www.nocutnews.co.kr/news/5648570  2021.10.31.  naver
# 0                http://www.etnews.com/20211029000216  2021.10.31.  naver
# 0   http://www.edaily.co.kr/news/newspath.asp?news...  2021.10.31.  naver
# 0       http://www.fnnews.com/news/202110311807193522  2021.10.31.  naver
# ..                                                ...          ...    ...
# 0   https://www.hani.co.kr/arti/economy/marketing/...  2021.10.08.  naver
# 0       http://www.fnnews.com/news/202110121420382008  2021.10.12.  naver
# 0   http://www.wowtv.co.kr/NewsCenter/News/Read?ar...  2021.10.18.  naver
# 0   https://economist.co.kr/2021/10/12/stock/stock...  2021.10.12.  naver
# 0        http://yna.kr/AKR20211006152200003?did=1195m  2021.10.06.  naver
#
# [2643 rows x 5 columns]

# %%
naver('네이버')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# CHIEF EXECUTIVE
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
#                                            title  \
# 0                    네이버의 '키워드 리뷰' 새 가게평가 문화로 호평
# 0                    네이버-이마트-쿠팡, 빅커머스 1위 쟁탈전 본격화
# 0   “네이버 검색량 보니···” 尹 ‘398’ 리스크 재확인[데이터로 본 정치민심]
# 0            [IT돋보기] 네이버 검색, AI 재탄생…"정답에 취향 더한다"
# 0           네이버 '키워드 리뷰' 개시…기존 '별점 리뷰' 내년 1분기 중단
# ..                                           ...
# 0             [더벨]금융사업 구조조정…'급한' 카카오 vs '여유' 네이버
# 0               '테크래시' 직격탄 맞은 빅테크…네이버는 규제 청정 구역?
# 0                  플랫폼 논란 예견했나...네이버가 5년전 심은 '꽃'
# 0   [단독] 네이버 해피빈 ‘직장갑질’ 폭로 뒤 “가해자 구명 탄원서 써달라” 요구
# 0              네이버에 종속된 저축은행…'광고비 부담' 결국 고객에게 간다
#
#                                              abstract  \
# 0   네이버가 최근 도입한 '키워드 리뷰'가 새로운 가게 평가 문화로 각광받고 있다. 키...
# 0   규제 당국의 신세계 그룹 이마트-이베이코리아 기업결합 승인으로, 국내 이커머스 시장...
# 0   국민의힘 대선 경선 투표 시작을 하루 앞둔 31일, 유력 주자인 윤 후보가 풀어야 ...
# 0   #네이버에 캠핑을 검색하자, ▲캠핑 준비물 리스트 ▲초보캠핑 ▲캠핑장비 ▲감성캠핑 ...
# 0   네이버는 오프라인 중소상공인(SME) 대상 새 리뷰 시스템 '키워드 리뷰'를 26일...
# ..                                                ...
# 0   금융소비자보호법이 조만간 실시되면 네이버와 카카오의 금융사업은 좀 더 타이트한 규제...
# 0   미국 유럽 등의 빅테크 규제가 국내에서도 확산될 우려가 커지면서 국내 증시에서도 네...
# 0   " 2016년 당시 한성숙 네이버 서비스총괄부사장(현 대표)은 '프로젝트 꽃'을 발...
# 0   최근 직장 내 괴롭힘 피해 폭로가 나온 네이버 해피빈 재단 관계자들이 가해자로 지목...
# 0   네이버 등 빅테크 플랫폼의 영향력이 커지면서 저축은행들의 광고비 규모도 덩달아 커진...
#
#                                                   url         date engine
# 0       http://www.fnnews.com/news/202110311507252414  2021.10.31.  naver
# 0         https://zdnet.co.kr/view/?no=20211029184850  2021.10.29.  naver
# 0         https://www.sedaily.com/NewsView/22SYCNEBGU  2021.10.31.  naver
# 0                 http://www.inews24.com/view/1416237  2021.10.28.  naver
# 0        http://yna.kr/AKR20211027080500017?did=1195m  2021.10.27.  naver
# ..                                                ...          ...    ...
# 0   http://www.thebell.co.kr/front/free/contents/n...  2021.09.14.  naver
# 0   http://www.newstomato.com/ReadNews.aspx?no=107...  2021.09.14.  naver
# 0   http://news.mt.co.kr/mtview.php?no=20210913160...  2021.09.14.  naver
# 0   https://www.hani.co.kr/arti/society/society_ge...  2021.09.14.  naver
# 0   http://news.mt.co.kr/mtview.php?no=20210913152...  2021.09.14.  naver
#
# [3939 rows x 5 columns]

# %%
naver('기업은행')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1fe6ae35e47e> in <module>
# ----> 1 naver('기업은행')
#
# <ipython-input-4-d97688dec4ba> in naver(search)
#      99         else:
#     100             start += 10
# --> 101         time.sleep(0.5)
#     102
#     103         print('crawling...')
#
# KeyboardInterrupt:

# %%
import pandas as pd
import bs4
from urllib.request import urlopen
import urllib
import tkinter as tk
from tkinter import messagebox
import datetime
import time
import re


def kortime2engtime(time_string):
    today = datetime.datetime.today()
    number = int(re.findall('\d+', time_string)[0])
    kortime = ''.join(re.findall("[^0-9]",time_string))
    if kortime == '일' :
        before_date = datetime.timedelta(days=number)
    elif kortime == '분':
        before_date= datetime.timedelta(minutes=number)
    elif kortime == '시간' :
        before_date = datetime.timedelta(hours=number)
    elif kortime == '초' :
        before_date = datetime.timedelta(seconds=number)
    else:
        return time_string
    save_date = (today-before_date).strftime('%Y.%m.%d')
    return save_date


def naver(search,start_date,end_date):
    searching = '''{}'''.format(search)
    searching = searching.strip()
    df_list = []
    start = 1
    keyword = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', ' ', searching).split()
    op = re.findall('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', searching)

    plus = [keyword[0]]

    for index, value in enumerate(op):
        if value == '+':
            plus.extend([keyword[index+1]])

    new = keyword[0]
    for k,o in zip(keyword[1:],op):
        if len(keyword) ==1:
            stop = True
            break

        else:
            new += ' '+o+k
    word_encode = urllib.parse.quote(new)

    while True:
        url='''https://search.naver.com/search.naver?where=news&query={}&sm=tab_opt&sort=0&photo=3&field=0&pd=3&ds={}&de={}&start={}'''.format(word_encode,start_date,end_date,start)
        source = urlopen(url).read()
        source = bs4.BeautifulSoup(source, 'html.parser')
        title_path = source.find_all('a', {'class': 'news_tit'})
        abstract_path = source.find_all('a', {'class': 'api_txt_lines dsc_txt_wrap'})
        date_path = source.find_all('span', {'class': 'info'})

        if len(title_path) == 0:
            root = tk.Tk()
            msg = messagebox.showerror(title="Naver No news", message='please search other keyword')
            if msg == 'ok':
                root.destroy()
                break

        for i in range(len(title_path)):
            title = title_path[i].get('title')

            if all(key in title for key in plus):
                abstract = abstract_path[i].text
                link = title_path[i].get('href')
                date_txt = date_path[i].text
                date = kortime2engtime(date_txt.split()[0])
                df = pd.DataFrame(
                    {'title': [title], 'abstract': [abstract], 'url': [link], 'date': [date],
                        'engine': ['naver']})
                df_list.append(df)
             

        current_page = source.find_all('a', {'aria-pressed': 'true'})[0].text
        last_page = source.find_all('a', {'aria-pressed': 'false'})[-1].text
        if last_page == '문서 저장하기':
            break

        if int(current_page) >= int(last_page):
            break
        else:
            start += 10
        time.sleep(0.5)
        
        print('crawling...')

    if df_list:
            naver_df = pd.concat(df_list)
            st = ''.join(start_date.split('.')[1:])
            et = ''.join(end_date.split('.')[1:])
            naver_df.to_excel('''naver_{}_result_{}_{}.xlsx'''.format(searching,st,et),index=False)
            
            root2 = tk.Tk()
            msg = messagebox.showinfo(title='Save msg',message='Naver Save!')
            if msg == 'ok':
                root2.destroy()
            return naver_df
    else:
        root3 = tk.Tk()
        msg = messagebox.showerror(title = "Naver No news",message = 'please search other keyword')
        if msg == 'ok':
            root3.destroy()

#     df = pd.concat(df_list)
#     new = new.replace('|',' ')
#     st = ''.join(start_date.split('.')[1:])
#     et = ''.join(end_date.split('.')[1:])
#     df.to_excel('''naver_{}_result_{}_{}.xlsx'''.format(new,st,et), index=False)

# %%
naver('기업은행','2021.01.01','2021.10.31')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
#                                            title  \
# 0                   기업은행, 중기 근로자·소상공인 자녀에 장학금 전달
# 0                           라인업은 화려한데…안 풀리는 기업은행
# 0   IBK기업은행, 앱 설치하면 '포스기' 쉽게 사용…소상공인 카드결제기 비용 줄여
# 0                      기업은행 ‘글로벌 중소기업금융 콘퍼런스’ 개최
# 0              IBK기업은행, 中企용 'IBK CEO 금융비서' 기대해달라
# ..                                           ...
# 0                                    [인사]IBK기업은행
# 0                                   [인사] IBK기업은행
# 0              취임후 100번째 영업점 방문… 윤종원 기업은행장 소통 박차
# 0                 윤종원 IBK기업은행장 “중기 코로나 위기 극복 지원”
# 0                             [경제계 인사] IBK기업은행 외
#
#                                              abstract  \
# 0   기업은행이 코로나19 장기화로 어려움을 겪고 있는 중소기업 근로자 및 소상공인 자녀...
# 0   2020 도쿄 올림픽 대표팀 선수들을 다수 보유한 여자 프로배구 IBK기업은행이 3...
# 0   ◆ 간편 금융시대 ◆ 기업은행은 소상공인의 카드결제 단말기(POS) 유지 비용 부담...
# 0   IBK기업은행은 20일 창립 60주년을 기념해 서울 을지로 기업은행 본점에서 한국경...
# 0   문창환 디지털그룹 부행장 ◆ 디지털을 이끄는 금융인 ◆ "기업은행의 주 고객인 중소...
# ..                                                ...
# 0   ◆IBK기업은행 ◇부행장 승진 △금융소비자보호그룹 김은희 △CIB그룹 박주용 △디지...
# 0   ◇IBK기업은행 ◇부행장 승진 △금융소비자보호그룹 김은희 △CIB그룹 박주용 △디지...
# 0   윤종원(사진 오른쪽) 기업은행장이 혁신 중소기업 및 영업점들을 방문하면서 현장 소통...
# 0   윤종원 IBK기업은행장이 “올 상반기에 중소기업 대출 공급 비중을 확대해 일시적으로...
# 0   ▲IBK기업은행◇지역본부장급 승진▷강동지역본부 이상직▷남중지역본부 황인선▷경동·강원...
#
#                                                   url         date engine
# 0         https://www.sedaily.com/NewsView/22SXHYWPRM           8면  naver
# 0   https://www.khan.co.kr/sports/basketball-volle...           1면  naver
# 0   http://news.mk.co.kr/newsRead.php?no=1024098&y...  2021.10.31.  naver
# 0   https://www.khan.co.kr/economy/finance/article...  2021.10.27.  naver
# 0   http://news.mk.co.kr/newsRead.php?no=1006809&y...          B5면  naver
# ..                                                ...          ...    ...
# 0                http://www.etnews.com/20210114000072  2021.03.15.  naver
# 0   http://www.dt.co.kr/contents.html?article_no=2...          21면  naver
# 0   http://www.munhwa.com/news/view.html?no=202105...         A23면  naver
# 0   http://news.kmib.co.kr/article/view.asp?arcid=...          17면  naver
# 0   https://www.chosun.com/economy/stock-finance/2...         A18면  naver
#
# [240 rows x 5 columns]

# %%
naver('네이버','2021.01.01','2021.10.31')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
#                                         title  \
# 0                      "네이버 키워드 리뷰, 별점보다 좋아요"
# 0                네이버, 인플루언서 검색도 '묶고 모아서' 제공한다
# 0                 네이버 '에어서치' 공개…AI로 구글 검색에 맞불
# 0                      `정답→관심사`… 네이버 검색 확 바꾼다
# 0                          네이버 ‘키워드 리뷰’ 정식 출시
# ..                                        ...
# 0                  "네이버 0.1주 삽니다"…소수점 매매 이뤄질까
# 0   2000년 톱10 중 삼성전자만 남아…네이버·셀트리온·카카오 등 새 강자로
# 0    네이버 '쇼핑 내역' 마이데이터 공유대상 포함···12개 항목으로만 제공
# 0        ‘블루웨이브 리스크’ 누른 유동성?...카카오·네이버 모처럼 진격
# 0           브랜디, 네이버서 200억원 추가 투자 유치…연내 일본 진출
#
#                                              abstract  \
# 0   네이버가 최근 도입한 '키워드 리뷰'가 새로운 가게 평가 문화로 각광받고 있다. 키...
# 0   네이버가 통합검색에 이어 인플루언서 검색에서도 결과를 묶어 노출한다. 특정 콘텐츠를...
# 0   20년 써온 낡은 검색 확 바꿔 '캠핑' 검색하면 준비물 알려줘 검색 이유까지 간파...
# 0   AI '에어서치'로 검색 방향 잡아 개인맞춤형 스마트블록 형태로 콘텐츠 이전 대비 ...
# 0   네이버는 자사 새로운 리뷰 시스템 ‘키워드 리뷰’서비스(사진)가 정식 출시됐다고 2...
# ..                                                ...
# 0   류영준 카카오페이 대표 10만원이상 고가株 분할매수 금융위 "안전거래제도 고민" 커...
# 0   최근 5년 사이 시총 10위권을 지켜낸 곳은 삼성전자를 비롯해 현대차와 현대모비스,...
# 0   금융사와 빅테크가 첨예하게 대립했던 주문 내역 정보 제공이 본인신용정보관리업(마이데...
# 0   황소장에서 웅크리고 있던 국내 비대면(언택트) 업종 투 톱인 카카오(035720)와...
# 0   의류 전자상거래(이커머스) 플랫폼을 운영하는 브랜디는 네이버로부터 200억원 추가 ...
#
#                                                   url         date engine
# 0       http://www.fnnews.com/news/202110311812568315          20면  naver
# 0                http://www.etnews.com/20211029000204  2021.10.31.  naver
# 0   http://news.mk.co.kr/newsRead.php?no=1023222&y...          11면  naver
# 0   http://www.dt.co.kr/contents.html?article_no=2...  2021.10.31.  naver
# 0   http://news.heraldcorp.com/view.php?ud=2021102...         A18면  naver
# ..                                                ...          ...    ...
# 0   http://news.mk.co.kr/newsRead.php?no=209816&ye...         A10면  naver
# 0       https://news.joins.com/article/olink/23558094  2021.10.19.  naver
# 0         https://www.sedaily.com/NewsView/22IMQQRPI1          11면  naver
# 0         https://www.sedaily.com/NewsView/22H6E902IW          20면  naver
# 0   http://news.mt.co.kr/mtview.php?no=20210804093...  2021.08.04.  naver
#
# [2133 rows x 5 columns]

# %%
naver('삼성전자','2021.01.01','2021.10.31')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
#                                                 title  \
# 0                   실탄 120兆 든 삼성전자…美 반도체 공장·대형M&A 초읽기
# 0          메모리 겨울 온다는데...삼성전자 '낙관', 증권가도 '장밋빛 전망', 왜?
# 0                    삼성전자, 창립기념일 맞아 '삼성위크' 가전 프로모션 기획
# 0                      여전한 개미의 삼성전자 사랑…外人 물량 2.5조 받아내
# 0                   메모리반도체 날개 단 삼성전자...파운드리 1위 자신한 근거
# ..                                                ...
# 0                         1조 파운드리 계약…삼성전자 ‘10만전자’ 재시동
# 0                         1조 파운드리 계약…삼성전자 ‘10만전자’ 재시동
# 0                            삼성전자, 5G통신장비 국제 보안 인증 획득
# 0                         반도체 위탁생산 늘린다는 인텔…삼성전자에 수혜될까
# 0   [새해 ‘목표가 UP’ 리포트 716건 분석]삼성전자 21건 ‘최다’ ...현대위아...
#
#                                              abstract  \
# 0   삼성전자가 1일 창립 52주년을 맞는 가운데 120조원에 달하는 현금 실탄을 어디에...
# 0   D램 가격 하락은 삼성전자와 SK하이닉스 실적에도 적잖은 타격이 될 수 있지만, 정...
# 0   삼성전자가 창립 52주년을 맞아 글로벌 시장에서 주요 제품을 할인해 판매하는 '삼성...
# 0   삼성전자(005930)가 다시 6만전자로 내려가자 개인투자자들의 주워담기 강도도 거...
# 0   삼성전자가 올 4분기와 내년 메모리반도체 시장 업황을 두고 부품 수급 이슈가 장기화...
# ..                                                ...
# 0   승승장구하는 반도체 파운드리(위탁생산)를 원동력 삼아 삼성전자의 주가가 다시 ‘10...
# 0   승승장구하는 반도체 파운드리(위탁생산)를 원동력 삼아 삼성전자의 주가가 다시 ‘10...
# 0   CC 포털에 보안제품 등록 완료 삼성전자는 5세대(G) 이동통신장비에 대한 ‘국제 ...
# 0   업계에서는 인텔의 위탁생산 주요 계획에 세계 1위 파운드리 업체인 대만의 TSMC와...
# 0   특히 ‘국민주’ 삼성전자(005930)의 눈높이를 높이는 견해가 가장 많았고 목표가...
#
#                                                   url         date engine
# 0       http://www.fnnews.com/news/202110311807193522          16면  naver
# 0   https://hankookilbo.com/News/Read/A20211031132...           3면  naver
# 0                http://www.etnews.com/20211029000216  2021.10.31.  naver
# 0   http://www.edaily.co.kr/news/newspath.asp?news...           1면  naver
# 0   http://news.mt.co.kr/mtview.php?no=20211028141...  2021.10.30.  naver
# ..                                                ...          ...    ...
# 0   http://news.heraldcorp.com/view.php?ud=2021012...  2021.04.14.  naver
# 0   http://news.heraldcorp.com/view.php?ud=2021012...          14면  naver
# 0   http://www.munhwa.com/news/view.html?no=202101...          35면  naver
# 0   http://news.khan.co.kr/kh_news/khan_art_view.h...  2021.01.22.  naver
# 0         https://www.sedaily.com/NewsView/22HCRV8QW6          A5면  naver
#
# [1994 rows x 5 columns]
