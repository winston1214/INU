# %%
import pandas as pd
import bs4
from urllib.request import urlopen
import urllib
import time
import tkinter as tk
from tkinter import messagebox
import datetime
import time
import re
def kortime2engtime(time_string):
    today = datetime.datetime.today()
    number = int(re.findall('\d+', time_string)[0])
    kortime = ''.join(re.findall("[^0-9]",time_string))
    if kortime == '일' :
        before_date = datetime.timedelta(days=number)
    elif kortime == '분':
        before_date= datetime.timedelta(minutes=number)
    elif kortime == '시간' :
        before_date = datetime.timedelta(hours=number)
    elif kortime == '초' : 
        before_date = datetime.timedelta(seconds=number)
    else:
        return time_string
    save_date = (today-before_date).strftime('%Y.%m.%d')
    return save_date


def naver(search):
    searching = '''{}'''.format(search)
    searching = searching.strip()
    df_list = []
    start = 1
    start_date = '2021.01.02'
    end_date = '2021.10.16'
    keyword = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', ' ', searching).split()
    op = re.findall('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', searching)

    plus = [keyword[0]]

    for index, value in enumerate(op):
        if value == '+':
            plus.extend([keyword[index+1]])

    new = keyword[0]
    for k,o in zip(keyword[1:],op):
        if len(keyword) ==1:
            break
        else:
            new += ' '+o+k
    word_encode = urllib.parse.quote(new)

    while True:
        url='''https://search.naver.com/search.naver?where=news&query={}&sm=tab_opt&sort=0&photo=0&field=0&pd=3&ds={}&de={}&start={}'''.format(word_encode,start_date,end_date,start)
        source = urlopen(url).read()
        source = urlopen(url).read()
        source = bs4.BeautifulSoup(source, 'html.parser')
        title_path = source.find_all('a', {'class': 'news_tit'})
        abstract_path = source.find_all('a', {'class': 'api_txt_lines dsc_txt_wrap'})
        date_path = source.find_all('span', {'class': 'info'})
        for idx,v in enumerate(date_path):
            if v.find('i'):
                date_path.pop(idx)
        
        if len(title_path) == 0:
            root = tk.Tk()
            msg = messagebox.showerror(title="Naver No news", message='please search other keyword')
            if msg == 'ok':
                root.destroy()
                break

        for i in range(len(title_path)):
            title = title_path[i].get('title')

            if all(key in title for key in plus):
                abstract = abstract_path[i].text
                link = title_path[i].get('href')
                date_txt = date_path[i].text
                
                date = kortime2engtime(date_txt.split()[0])
                df = pd.DataFrame(
                    {'title': [title], 'abstract': [abstract], 'url': [link], 'date': [date],
                        'engine': ['naver']})
                df_list.append(df)
             

        current_page = source.find_all('a', {'aria-pressed': 'true'})[0].text
        last_page = source.find_all('a', {'aria-pressed': 'false'})[-1].text
        if last_page == '문서 저장하기':
            break

        if int(current_page) >= int(last_page):
            break
        else:
            start += 10
        time.sleep(0.5)
        
        print('crawling...')

    if df_list:
            naver_df = pd.concat(df_list)
            new = new.replace('|',' ')
            naver_df.to_excel('''naver_{}_result.xlsx'''.format(new),index=False)

            root2 = tk.Tk()
            msg = messagebox.showinfo(title='Save msg',message='Naver Save!')
            if msg == 'ok':
                root2.destroy()
            return naver_df
    else:
        root3 = tk.Tk()
        msg = messagebox.showerror(title = "Naver No news",message = 'please search other keyword')
        if msg == 'ok':
            root3.destroy()

# %%
naver('삼성전자')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
#                                  title  \
# 0             "20일 삼성전자 언팩, '이것' 공개된다"
# 0    "삼성전자 지금 사야 돈 번다"…개미들 2조 '줍줍'한 이유
# 0      떨어지는 삼성전자 잡는 개미들…열흘간 3조원 넘게 순매수
# 0        삼성전자가 미국기업도 아닌데…또 호출한 바이든, 왜?
# 0          삼성전자, 5G 업로드 세계 신기록 달성…비결은?
# ..                                 ...
# 0    삼성전자 3Q 반도체 매출, 파운드리 빼고도 세계 1위할 듯
# 0          [특징주] 삼성전자, 5일 7만2000원도 깨졌다
# 0     삼성전자 노사 오늘 첫 임금교섭…급여 50% 인상 성사되나
# 0                 삼성전자 온실가스 저감율 업체 최하위
# 0   파운드리시장 점유율 높인 TSMC, 삼성전자와 격차 더 벌렸다
#
#                                              abstract  \
# 0   삼성전자의 갤럭시S21 FE(팬에디션)가 이번 달 출시될 것이라는 전망이 나왔다. ...
# 0   개미(개인투자자)들의 삼성전자 사랑이 여전하다. 삼성전자가 3거래일 만에 '7만전자...
# 0   주가, 연고점 대비 29% 하락…10개월 만에 '6만전자' 증권가, 반도체 업황 우...
# 0   조 바이든 미국 대통령이 미국 내 물류대란을 해결하기 위해 민간기업의 협조를 요청하...
# 0   삼성전자는 5G 이동통신 업로드 속도에서 세계 최고 기록을 달성했다고 15일 밝혔다...
# ..                                                ...
# 0   삼성전자가 올해 3분기 파운드리(반도체 위탁생산) 매출을 제외하고도 글로벌 반도체 ...
# 0   삼성전자가 5일 7만1000원대까지 떨어지는 등 연중 최저가를 기록했다. 삼성전자는...
# 0   삼성전자 노사가 5일 창사 이래 첫 임금교섭에 돌입한다. 이번 교섭은 지난해 5월 ...
# 0   우리나라 반도체, 디스플레이, 전자산업 5대 기업의 불소가스(F-gas) 사용업체별...
# 0   반도체 위탁생산(파운드리) 시장에서 세계 1위 TSMC와 2위 삼성전자의 격차가 더...
#
#                                                   url         date engine
# 0   http://moneys.mt.co.kr/news/mwView.php?no=2021...   2021.10.15  naver
# 0   https://www.hankyung.com/finance/article/20211...   2021.10.16  naver
# 0        http://yna.kr/AKR20211013173100002?did=1195m   2021.10.14  naver
# 0   http://news.mt.co.kr/mtview.php?no=20211015154...   2021.10.16  naver
# 0   http://www.sisaon.co.kr/news/articleView.html?...   2021.10.15  naver
# ..                                                ...          ...    ...
# 0   https://view.asiae.co.kr/article/2021092010181...  2021.09.20.  naver
# 0   http://news.heraldcorp.com/view.php?ud=2021100...  2021.10.05.  naver
# 0   https://www.asiatoday.co.kr/view.php?key=20211...  2021.10.05.  naver
# 0   http://www.kmaeil.com/news/articleView.html?id...  2021.10.06.  naver
# 0                 http://www.inews24.com/view/1408580  2021.10.01.  naver
#
# [2747 rows x 5 columns]

# %%
naver('네이버')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-8570c255c72f> in <module>
# ----> 1 naver('네이버')
#
# <ipython-input-8-656622ac22a6> in naver(search)
#      78                 date_txt = date_path[i].text
#      79
# ---> 80                 date = kortime2engtime(date_txt.split()[0])
#      81                 df = pd.DataFrame(
#      82                     {'title': [title], 'abstract': [abstract], 'url': [link], 'date': [date],
#
# <ipython-input-8-656622ac22a6> in kortime2engtime(time_string)
#      11 def kortime2engtime(time_string):
#      12     today = datetime.datetime.today()
# ---> 13     number = int(re.findall('\d+', time_string)[0])
#      14     kortime = ''.join(re.findall("[^0-9]",time_string))
#      15     if kortime == '일' :
#
# IndexError: list index out of range

# %%
naver('기업은행')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
