# %%
import pandas as pd
import bs4
from urllib.request import urlopen
import urllib
import time
import tkinter as tk
from tkinter import messagebox
import datetime
import time
import re
import numpy as np
def kortime2engtime(time_string):
    today = datetime.datetime.today()
    number = int(re.findall('\d+', time_string)[0])
    kortime = ''.join(re.findall("[^0-9]",time_string))
    if kortime == '일' :
        before_date = datetime.timedelta(days=number)
    elif kortime == '분':
        before_date= datetime.timedelta(minutes=number)
    elif kortime == '시간' :
        before_date = datetime.timedelta(hours=number)
    elif kortime == '초' : 
        before_date = datetime.timedelta(seconds=number)
    else:
        return time_string
    save_date = (today-before_date).strftime('%Y.%m.%d')
    return save_date


def naver(search):
    searching = '''{}'''.format(search)
    searching = searching.strip()
    df_list = []
    start = 1
    start_date = '2021.01.01'
    end_date = '2021.10.31'
    keyword = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', ' ', searching).split()
    op = re.findall('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', searching)

    plus = [keyword[0]]

    for index, value in enumerate(op):
        if value == '+':
            plus.extend([keyword[index+1]])

    new = keyword[0]
    for k,o in zip(keyword[1:],op):
        if len(keyword) ==1:
            break
        else:
            new += ' '+o+k
    word_encode = urllib.parse.quote(new)
    
    while True:
        url='''https://search.naver.com/search.naver?where=news&query={}&sm=tab_opt&sort=0&photo=0&field=0&pd=3&ds={}&de={}&start={}'''.format(word_encode,start_date,end_date,start)
        source = urlopen(url).read()
        source = urlopen(url).read()
        source = bs4.BeautifulSoup(source, 'html.parser')
        title_path = source.find_all('a', {'class': 'news_tit'})
        abstract_path = source.find_all('a', {'class': 'api_txt_lines dsc_txt_wrap'})
        date_path = source.find_all('span', {'class': 'info'})
        for idx,v in enumerate(date_path):
            if v.find('i'):
                date_path.pop(idx)

        if len(title_path) == 0:
            root = tk.Tk()
            msg = messagebox.showerror(title="Naver No news", message='please search other keyword')
            if msg == 'ok':
                root.destroy()
                break

        for i in range(len(title_path)):
            title = title_path[i].get('title')

            if all(key in title for key in plus):
                abstract = abstract_path[i].text
                link = title_path[i].get('href')
                date_txt = date_path[i].text
                try:
                    date = kortime2engtime(date_txt.split()[0])
                except:
                    date = date_txt
                    print(date)
                    pass
                df = pd.DataFrame(
                    {'title': [title], 'abstract': [abstract], 'url': [link], 'date': [date],
                        'engine': ['naver']})
                df_list.append(df)


        current_page = source.find_all('a', {'aria-pressed': 'true'})[0].text
        last_page = source.find_all('a', {'aria-pressed': 'false'})[-1].text
        if last_page == '문서 저장하기':
            break

        if int(current_page) >= int(last_page):
            break
        else:
            start += 10
        time.sleep(0.5)

        print('crawling...')


    if df_list:
            naver_df = pd.concat(df_list)
            new = new.replace('|',' ')
            naver_df.to_excel('''naver_{}_result.xlsx'''.format(new),index=False)

            root2 = tk.Tk()
            msg = messagebox.showinfo(title='Save msg',message='Naver Save!')
            if msg == 'ok':
                root2.destroy()
            return naver_df
    else:
        root3 = tk.Tk()
        msg = messagebox.showerror(title = "Naver No news",message = 'please search other keyword')
        if msg == 'ok':
            root3.destroy()

# %%
naver('삼성전자')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
#                                          title  \
# 0          삼성전자 52주년 창립기념식…이재용 불참 속 사장단만 참석 전망
# 0          北 매체, 삼성전자에 이어 '오징어게임'으로 '한미불공평' 부각
# 0             삼성전자, 창립기념일 맞아 '삼성위크' 가전 프로모션 기획
# 0               여전한 개미의 삼성전자 사랑…外人 물량 2.5조 받아내
# 0            실탄 120兆 든 삼성전자…美 반도체 공장·대형M&A 초읽기
# ..                                         ...
# 0   ‘실적왕’ 삼성전자, D램 값에 내년 실적 어둡다는데…비메모리 전망 ‘맑음’
# 0             삼성전자 '6만전자'로 추락...33조 투자한 개미 어쩌나
# 0               [특징주] 삼성전자, 다시 7만원 하회…0.8%대 약세
# 0            [개장시황] 삼성전자 2% 넘게 하락하며 장중 7만전자 깨져
# 0         상속세 납부 위해 법원에 공탁한 삼성家 삼성전자 주식 5조원 규모
#
#                                              abstract  \
# 0   11월1일인 삼성전자 창립기념식에는 이재용 부회장이 불참할 것으로 예상됩니다. 오늘...
# 0   핵심요약넷플릭스 계약 "南 제작비의 10%만 받아 美 기업 배만 불려" "南 영화제...
# 0   삼성전자가 창립 52주년을 맞아 글로벌 시장에서 주요 제품을 할인해 판매하는 '삼성...
# 0   삼성전자(005930)가 다시 6만전자로 내려가자 개인투자자들의 주워담기 강도도 거...
# 0   삼성전자가 1일 창립 52주년을 맞는 가운데 120조원에 달하는 현금 실탄을 어디에...
# ..                                                ...
# 0   삼성전자가 반도체 호황에 힘입어 분기 매출 70조원 시대를 열었다. 하지만 디(D)...
# 0   삼성전자 주가가 7만원 밑으로 추락하면서 실적 호재를 믿고 투자한 개인 투자자들이 ...
# 0   삼성전자가 다시 7만원대 아래로 떨어졌다. 18일 오전 9시 16분 현재 삼성전자는...
# 0   시가총액 상위 주요 종목 가운데 삼성전자는 전 거래일 7만1500원보다 2.24% ...
# 0   이부진, 지난달 1조원 규모 삼성전자 주식 법원 공탁 이재용 삼성전자 부회장 등 삼...
#
#                                                   url         date engine
# 0   https://biz.sbs.co.kr/article_hub/20000036495?...  2021.10.31.  naver
# 0            https://www.nocutnews.co.kr/news/5648570  2021.10.31.  naver
# 0                http://www.etnews.com/20211029000216  2021.10.31.  naver
# 0   http://www.edaily.co.kr/news/newspath.asp?news...  2021.10.31.  naver
# 0       http://www.fnnews.com/news/202110311807193522  2021.10.31.  naver
# ..                                                ...          ...    ...
# 0   https://www.hani.co.kr/arti/economy/marketing/...  2021.10.08.  naver
# 0       http://www.fnnews.com/news/202110121420382008  2021.10.12.  naver
# 0   http://www.wowtv.co.kr/NewsCenter/News/Read?ar...  2021.10.18.  naver
# 0   https://economist.co.kr/2021/10/12/stock/stock...  2021.10.12.  naver
# 0        http://yna.kr/AKR20211006152200003?did=1195m  2021.10.06.  naver
#
# [2643 rows x 5 columns]

# %%
naver('네이버')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# CHIEF EXECUTIVE
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
#                                            title  \
# 0                    네이버의 '키워드 리뷰' 새 가게평가 문화로 호평
# 0                    네이버-이마트-쿠팡, 빅커머스 1위 쟁탈전 본격화
# 0   “네이버 검색량 보니···” 尹 ‘398’ 리스크 재확인[데이터로 본 정치민심]
# 0            [IT돋보기] 네이버 검색, AI 재탄생…"정답에 취향 더한다"
# 0           네이버 '키워드 리뷰' 개시…기존 '별점 리뷰' 내년 1분기 중단
# ..                                           ...
# 0             [더벨]금융사업 구조조정…'급한' 카카오 vs '여유' 네이버
# 0               '테크래시' 직격탄 맞은 빅테크…네이버는 규제 청정 구역?
# 0                  플랫폼 논란 예견했나...네이버가 5년전 심은 '꽃'
# 0   [단독] 네이버 해피빈 ‘직장갑질’ 폭로 뒤 “가해자 구명 탄원서 써달라” 요구
# 0              네이버에 종속된 저축은행…'광고비 부담' 결국 고객에게 간다
#
#                                              abstract  \
# 0   네이버가 최근 도입한 '키워드 리뷰'가 새로운 가게 평가 문화로 각광받고 있다. 키...
# 0   규제 당국의 신세계 그룹 이마트-이베이코리아 기업결합 승인으로, 국내 이커머스 시장...
# 0   국민의힘 대선 경선 투표 시작을 하루 앞둔 31일, 유력 주자인 윤 후보가 풀어야 ...
# 0   #네이버에 캠핑을 검색하자, ▲캠핑 준비물 리스트 ▲초보캠핑 ▲캠핑장비 ▲감성캠핑 ...
# 0   네이버는 오프라인 중소상공인(SME) 대상 새 리뷰 시스템 '키워드 리뷰'를 26일...
# ..                                                ...
# 0   금융소비자보호법이 조만간 실시되면 네이버와 카카오의 금융사업은 좀 더 타이트한 규제...
# 0   미국 유럽 등의 빅테크 규제가 국내에서도 확산될 우려가 커지면서 국내 증시에서도 네...
# 0   " 2016년 당시 한성숙 네이버 서비스총괄부사장(현 대표)은 '프로젝트 꽃'을 발...
# 0   최근 직장 내 괴롭힘 피해 폭로가 나온 네이버 해피빈 재단 관계자들이 가해자로 지목...
# 0   네이버 등 빅테크 플랫폼의 영향력이 커지면서 저축은행들의 광고비 규모도 덩달아 커진...
#
#                                                   url         date engine
# 0       http://www.fnnews.com/news/202110311507252414  2021.10.31.  naver
# 0         https://zdnet.co.kr/view/?no=20211029184850  2021.10.29.  naver
# 0         https://www.sedaily.com/NewsView/22SYCNEBGU  2021.10.31.  naver
# 0                 http://www.inews24.com/view/1416237  2021.10.28.  naver
# 0        http://yna.kr/AKR20211027080500017?did=1195m  2021.10.27.  naver
# ..                                                ...          ...    ...
# 0   http://www.thebell.co.kr/front/free/contents/n...  2021.09.14.  naver
# 0   http://www.newstomato.com/ReadNews.aspx?no=107...  2021.09.14.  naver
# 0   http://news.mt.co.kr/mtview.php?no=20210913160...  2021.09.14.  naver
# 0   https://www.hani.co.kr/arti/society/society_ge...  2021.09.14.  naver
# 0   http://news.mt.co.kr/mtview.php?no=20210913152...  2021.09.14.  naver
#
# [3939 rows x 5 columns]

# %%
naver('기업은행')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1fe6ae35e47e> in <module>
# ----> 1 naver('기업은행')
#
# <ipython-input-4-d97688dec4ba> in naver(search)
#      99         else:
#     100             start += 10
# --> 101         time.sleep(0.5)
#     102
#     103         print('crawling...')
#
# KeyboardInterrupt:

# %%
import pandas as pd
import bs4
from urllib.request import urlopen
import urllib
import tkinter as tk
from tkinter import messagebox
import datetime
import time
import re


def kortime2engtime(time_string):
    today = datetime.datetime.today()
    number = int(re.findall('\d+', time_string)[0])
    kortime = ''.join(re.findall("[^0-9]",time_string))
    if kortime == '일' :
        before_date = datetime.timedelta(days=number)
    elif kortime == '분':
        before_date= datetime.timedelta(minutes=number)
    elif kortime == '시간' :
        before_date = datetime.timedelta(hours=number)
    elif kortime == '초' :
        before_date = datetime.timedelta(seconds=number)
    else:
        return time_string
    save_date = (today-before_date).strftime('%Y.%m.%d')
    return save_date


def naver(search,start_date,end_date):
    searching = '''{}'''.format(search)
    searching = searching.strip()
    df_list = []
    start = 1
    keyword = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', ' ', searching).split()
    op = re.findall('[-=+,#/\?:^$.@*\"※~&%ㆍ!』\\‘|\(\)\[\]\<\>`\'…》]', searching)

    plus = [keyword[0]]

    for index, value in enumerate(op):
        if value == '+':
            plus.extend([keyword[index+1]])

    new = keyword[0]
    for k,o in zip(keyword[1:],op):
        if len(keyword) ==1:
            stop = True
            break

        else:
            new += ' '+o+k
    word_encode = urllib.parse.quote(new)

    while True:
        url='''https://search.naver.com/search.naver?where=news&query={}&sm=tab_opt&sort=0&photo=4&field=0&pd=3&ds={}&de={}&start={}'''.format(word_encode,start_date,end_date,start)
        source = urlopen(url).read()
        source = bs4.BeautifulSoup(source, 'html.parser')
        title_path = source.find_all('a', {'class': 'news_tit'})
        abstract_path = source.find_all('a', {'class': 'api_txt_lines dsc_txt_wrap'})
        date_path = source.find_all('span', {'class': 'info'})

        if len(title_path) == 0:
            root = tk.Tk()
            msg = messagebox.showerror(title="Naver No news", message='please search other keyword')
            if msg == 'ok':
                root.destroy()
                break

        for i in range(len(title_path)):
            title = title_path[i].get('title')

            if all(key in title for key in plus):
                abstract = abstract_path[i].text
                link = title_path[i].get('href')
                date_txt = date_path[i].text
                date = kortime2engtime(date_txt.split()[0])
                df = pd.DataFrame(
                    {'title': [title], 'abstract': [abstract], 'url': [link], 'date': [date],
                        'engine': ['naver']})
                df_list.append(df)
             

        current_page = source.find_all('a', {'aria-pressed': 'true'})[0].text
        last_page = source.find_all('a', {'aria-pressed': 'false'})[-1].text
        if last_page == '문서 저장하기':
            break

        if int(current_page) >= int(last_page):
            break
        else:
            start += 10
        time.sleep(0.5)
        
        print('crawling...')

    if df_list:
            naver_df = pd.concat(df_list)
            naver_df.to_excel('''naver_{}_result.xlsx'''.format(searching),index=False)

            root2 = tk.Tk()
            msg = messagebox.showinfo(title='Save msg',message='Naver Save!')
            if msg == 'ok':
                root2.destroy()
            return naver_df
    else:
        root3 = tk.Tk()
        msg = messagebox.showerror(title = "Naver No news",message = 'please search other keyword')
        if msg == 'ok':
            root3.destroy()

    df = pd.concat(df_list)
    new = new.replace('|',' ')
    st = ''.join(start_date.split('.')[1:])
    et = ''.join(end_date.split('.')[1:])
    df.to_excel('''naver_{}_result_{}_{}.xlsx'''.format(new,st,et), index=False)

# %%
naver('삼성전자','2021.01.01','2021.10.31')
# Out:
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
# crawling...
#                                       title  \
# 0     삼성전자, 국내 최대 20㎏ 용량 비스포크 그랑데 건조기 AI 선봬
# 0   SK매직, '삼성전자'와 가전 렌탈서비스 전국 SKT 매장 확대 판매,
# 0               삼성전자, ‘삼성 개발자 콘퍼런스 2021’ 개최
# 0    삼성전자, 세계 3분기 스마트폰 판매량 1위…"4분기 애플이 선두로"
# 0       SKT, 삼성전자와 손잡고 생활 가전 '렌탈 구독 서비스' 시행
# ..                                      ...
# 0       삼성전자, 유럽서 버추얼 행사 개최… '비스포크 홈' 제품 소개
# 0       삼성전자, 원스톱 AI 가전 관리 서비스 '홈케어 매니저' 확대
# 0       삼성전자, 원스톱 AI 가전 관리 서비스 '홈케어 매니저' 확대
# 0            삼성전자서비스, 다문화가정 청소년 자립 위한 후원 실시
# 0           삼성전자, 15년 간 우수 기능인력 양성 산실로 '우뚝'
#
#                                              abstract  \
# 0   삼성전자가 국내 최대 건조 용량인 비스포크 그랑데 건조기 인공지능(AI)을 28일 ...
# 0   SK매직(대표 윤요섭)은 삼성전자 ‘스페셜 렌탈 서비스’를 전국 3300여개 SKT...
# 0   서울--(뉴스와이어) 삼성전자가 26일(미국 시각) ‘삼성 개발자 콘퍼런스 2021...
# 0   삼성전자가 지난 3분기 세계 스마트폰 판매량 1위 자리를 지킨 가운데 애플이 샤오미...
# 0   사진=SKT SK텔레콤(SKT)은 오는 29일부터 자사 3300여개의 오프라인 유통...
# ..                                                ...
# 0   삼성전자가 12일(현지시간) 유럽 소비자를 대상으로 한 버추얼 프레스콘퍼런스 'Li...
# 0   삼성전자가 가전제품의 고장 여부를 인공지능(AI)으로 진단하고, 사용자가 스스로 관...
# 0   삼성전자가 가전제품의 고장 여부를 인공지능(AI)으로 진단하고, 사용자가 스스로 관...
# 0   삼성전자서비스가 다문화가정 청소년의 자립을 돕기 위한 사회공헌 활동을 적극 실시하고...
# 0   전국 기능 경기 대회 후원...15년 간 누적 후원금 100억 원에 육박 삼성전자가...
#
#                                                   url         date engine
# 0       http://www.fnnews.com/news/202110280911311632  2021.10.28.  naver
# 0   http://www.thebigdata.co.kr/view.php?ud=202110...  2021.10.28.  naver
# 0   https://www.newswire.co.kr/newsRead.php?no=933017  2021.10.27.  naver
# 0   https://www.asiatime.co.kr/article/20211030500021  2021.10.30.  naver
# 0   http://www.pressm.kr/news/articleView.html?idx...  2021.10.28.  naver
# ..                                                ...          ...    ...
# 0   http://www.newscj.com/news/articleView.html?id...  2021.10.12.  naver
# 0        http://yna.kr/RPR20211021001100353?did=1198m  2021.10.21.  naver
# 0        http://yna.kr/RPR20211021001100353?did=1198m  2021.10.21.  naver
# 0        http://yna.kr/RPR20211019003300353?did=1198m  2021.10.19.  naver
# 0   http://www.g-enews.com/ko-kr/news/article/news...  2021.10.05.  naver
#
# [354 rows x 5 columns]

# %%
pd.read_csv('naver_삼성전자_result.xlsx')
